# %% [markdown]
# ##Create coordinate file which will be used when downloading street-view and satellite images

# %%
# Install packages
# !pip install geopandas
# !pip install pysal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.2/220.2 kB 11.4 MB/s eta 0:00:00
# ...

# %%
# import modules (old)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import modules (new)
import geopandas as gpd
import networkx as nx
from pysal.lib import weights
from pysal.lib import cg as geometry

# %%
# define the mounting point on Google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Switch to Colab Notebooks.
# Mac system
# !cd '/content/drive/My Drive/Colab Notebooks/data/'
# Windows system
# %cd /content/drive/MyDrive/UF summer research data examples
# Out:
# /content/drive/MyDrive/UF summer research data examples

# %%
california_shapefile = gpd.read_file('tl_2022_06_tract/tl_2022_06_tract.shp') # read the shapefile

# %%
print(type(california_shapefile))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
california_shapefile
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  \
# 0         06      037  137504  06037137504  1375.04  Census Tract 1375.04
# 1         06      037  138000  06037138000     1380     Census Tract 1380
# 2         06      037  139200  06037139200     1392     Census Tract 1392
# 3         06      087  120901  06087120901  1209.01  Census Tract 1209.01
# 4         06      087  120902  06087120902  1209.02  Census Tract 1209.02
# ...      ...      ...     ...          ...      ...                   ...
# 9124      06      001  444500  06001444500     4445     Census Tract 4445
# 9125      06      001  450200  06001450200     4502     Census Tract 4502
# 9126      06      001  450300  06001450300     4503     Census Tract 4503
# 9127      06      105  000500  06105000500        5        Census Tract 5
# 9128      06      037  207400  06037207400     2074     Census Tract 2074
#
#       MTFCC FUNCSTAT       ALAND   AWATER     INTPTLAT      INTPTLON  \
# ...

# %%
california_shapefile['INTPTLAT']
# Out:
# 0       +34.1480383
# 1       +34.1488008
# 2       +34.1756961
# 3       +37.0781624
# 4       +37.0628452
#            ...
# 9124    +37.5342653
# 9125    +37.7224277
# 9126    +37.7106517
# 9127    +40.3425806
# 9128    +34.0562223
# Name: INTPTLAT, Length: 9129, dtype: object

# %%
california_shapefile['INTPTLON']
# Out:
# 0       -118.5720594
# 1       -118.5910495
# 2       -118.5246446
# 3       -122.0154263
# 4       -122.0106243
#             ...
# 9124    -122.0273658
# 9125    -121.9154123
# 9126    -121.9177272
# 9127    -123.2757792
# 9128    -118.2466420
# Name: INTPTLON, Length: 9129, dtype: object

# %%
california_shapefile[['GEOID','INTPTLAT','INTPTLON']].to_excel('coordinate.xlsx', index=False)
